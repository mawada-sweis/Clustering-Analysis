# %% [markdown]
# ## DBSCAN Algorithm
# Density-Based Spatial Clustering of Applications with Noise
#
# - Dimensionality Reduction method: PCA.
# - Hyperparameters: EPS (determined using K distance graph), MinSamples.

# %%
# libraries
import pandas as pd
import numpy as np
import sys

# modelling - dbscan
from sklearn.cluster import DBSCAN
from sklearn.neighbors import NearestNeighbors

# dimensionality reduction 
from sklearn.decomposition import PCA

# visulaization
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib notebook

# Calling functions 
sys.path.insert(0, '../src/utils/')
import dbscan
import EDA

# %% [markdown]
# ### Reading Data

# %%
# Reading data 
minmax_data = pd.read_csv('../data/processed/data_scaled_minmax.csv')

# Print the shape of data
minmax_data.shape
# Out:
# (3346, 231)

# %%
# Reading data 
standard_data = pd.read_csv('../data/processed/data_scaled_standard.csv')

# Print the shape of data
standard_data.shape
# Out:
# (3346, 231)

# %% [markdown]
# ### DBSCAN on 2 Dimensiones and MinMax-Scaled data.

# %%
# Create a PCA On 2 components. 
X_2reduced = dbscan.create_pca(minmax_data, 2)
# Out:
# Explained variance ratio for each component: [0.12570507 0.06839946]

# %%
# Use K distance graph to determine the eps value. 
dbscan.get_kdistances(X_2reduced,4)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Based on the graph, I will choose eps = 0.1 <br>
# I will try these values for MinSamples = [10, 5, 20].

# %%
# Perform dbscan algo
clusters = dbscan.perform_dbscan(X_2reduced, 0.1 , 10)

# Print the number of clusters
print("Number of Clusters = ",len(set(clusters)))
# Out:
# Number of Clusters =  6

# %%
EDA.create_scatterplot(X_2reduced[:, 0], X_2reduced[:, 1], xlabel='PC1', ylabel='PC2', colors=clusters, title='DBSCAN Clustering - 2D [0.1, 10]')

# %%
# Perform dbscan algo
clusters = dbscan.perform_dbscan(X_2reduced, 0.1 , 5)

# Print the number of clusters
print("Number of Clusters = ",len(set(clusters)))
# Out:
# Number of Clusters =  17

# %%
EDA.create_scatterplot(X_2reduced[:, 0], X_2reduced[:, 1], xlabel='PC1', ylabel='PC2', colors=clusters, title='DBSCAN Clustering - 2D [0.1, 5]')

# %%
# Perform dbscan algo
clusters = dbscan.perform_dbscan(X_2reduced, 0.1 , 20)

# Print the number of clusters
print("Number of Clusters = ",len(set(clusters)))
# Out:
# Number of Clusters =  6

# %%
EDA.create_scatterplot(X_2reduced[:, 0], X_2reduced[:, 1], xlabel='PC1', ylabel='PC2', colors=clusters, title='DBSCAN Clustering - 2D [0.1, 20]')

# %% [markdown]
# ### DBSCAN on 2 Dimensiones and Standard-Scaled data.

# %%
# Create a PCA On 2 components. 
X_2reduced = dbscan.create_pca(standard_data, 2)
# Out:
# Explained variance ratio for each component: [0.13291958 0.07575221]

# %%
# Use K distance graph to determine the eps value. 
dbscan.get_kdistances(X_2reduced,4)

# %% [markdown]
# Based on the graph, I will choose eps = 0.25 <br>
# I will try these values for MinSamples = [10, 5, 20].

# %%
# Perform dbscan algo
clusters = dbscan.perform_dbscan(X_2reduced, 0.25 , 10)

# Print the number of clusters
print("Number of Clusters = ",len(set(clusters)))
# Out:
# Number of Clusters =  12

# %%
EDA.create_scatterplot(X_2reduced[:, 0], X_2reduced[:, 1], xlabel='PC1', ylabel='PC2', colors=clusters, title='DBSCAN Clustering - 2D [0.25, 10]')

# %%
# Perform dbscan algo
clusters = dbscan.perform_dbscan(X_2reduced, 0.1 , 5)

# Print the number of clusters
print("Number of Clusters = ",len(set(clusters)))
# Out:
# Number of Clusters =  79

# %%
EDA.create_scatterplot(X_2reduced[:, 0], X_2reduced[:, 1], xlabel='PC1', ylabel='PC2', colors=clusters, title='DBSCAN Clustering - 2D [0.25, 5]')

# %%
# Perform dbscan algo
clusters = dbscan.perform_dbscan(X_2reduced, 0.25 , 20)

# Print the number of clusters
print("Number of Clusters = ",len(set(clusters)))
# Out:
# Number of Clusters =  9

# %%
EDA.create_scatterplot(X_2reduced[:, 0], X_2reduced[:, 1], xlabel='PC1', ylabel='PC2', colors=clusters, title='DBSCAN Clustering - 2D [0.25, 20]')

# %% [markdown]
# MinMax scaled data is providing better results than standard scaled data.

# %% [markdown]
# #### DBSCAN on 3 Dimensiones and MinMax-Scaled Data.

# %%
# Create a PCA on 3 components
X_3reduced = dbscan.create_pca(minmax_data, 3)
# Out:
# Explained variance ratio for each component: [0.12570507 0.06839946 0.0525458 ]

# %%
# Use K distance graph to determine the eps value. 
dbscan.get_kdistances(X_3reduced,4)

# %% [markdown]
# Based on the graph, I will choose eps = 0.25 <br>
# I will try these values for min_samples = [10, 5, 20].

# %%
# Perform dbscan algo
clusters = dbscan.perform_dbscan(X_3reduced, 0.25 , 10)

# Print the number of clusters
print("Number of Clusters = ",len(set(clusters)))
# Out:
# Number of Clusters =  9

# %%
EDA.create_3d_scatter_plot(X_3reduced, xlabel="PC1", ylabel="PC2", zlabel="PC3", title="DBSCAN Clustering - 3D [0.25, 10]", labels=clusters)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# Perform dbscan algo
clusters = dbscan.perform_dbscan(X_3reduced, 0.25 , 5)

# Print the number of clusters
print("Number of Clusters = ",len(set(clusters)))
# Out:
# Number of Clusters =  12

# %%
EDA.create_3d_scatter_plot(X_3reduced, xlabel="PC1", ylabel="PC2", zlabel="PC3", title="DBSCAN Clustering - 3D [0.25, 5]", labels=clusters)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# Perform dbscan algo
clusters = dbscan.perform_dbscan(X_3reduced, 0.25 , 20)

# Print the number of clusters
print("Number of Clusters = ",len(set(clusters)))
# Out:
# Number of Clusters =  5

# %%
EDA.create_3d_scatter_plot(X_3reduced, xlabel="PC1", ylabel="PC2", zlabel="PC3", title="DBSCAN Clustering - 3D [0.25, 20]", labels=clusters)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# #### DBSCAN on 3 Dimensiones and Standard-Scaled data.

# %%
# Create a PCA on 3 components
X_3reduced = dbscan.create_pca(standard_data, 3)
# Out:
# Explained variance ratio for each component: [0.13291958 0.07575221 0.06823918]

# %%
# Use K distance graph to determine the eps value. 
dbscan.get_kdistances(X_3reduced,4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9360/1083692434.py in <module>
#       1 # Use K distance graph to determine the eps value.
# ----> 2 dbscan.get_kdistances(X_3reduced,4)
#
# ~\Clustering\Clustering-Analysis\models\../src/utils\dbscan.py in get_kdistances(data, k)
#      60
#      61     # Plot the distances
# ---> 62     plt.plot(distances)
#      63     plt.xlabel('Points')
#      64     plt.ylabel(f"Distance to {k}th nearest neighbor")
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3017 @_copy_docstring_and_deprecators(Axes.plot)
#    3018 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 3019     return gca().plot(
#    3020         *args, scalex=scalex, scaley=scaley,
#    3021         **({"data": data} if data is not None else {}), **kwargs)
#
# TypeError: plot() missing 1 required positional argument: 'ys'

# %% [markdown]
# Based on the graph, I will choose eps = 0.8 <br>
# I will try these values for min_samples = [10, 5, 20].

# %%
# Perform dbscan algo
clusters = dbscan.perform_dbscan(X_3reduced, 0.8 , 10)

# Print the number of clusters
print("Number of Clusters = ",len(set(clusters)))
# Out:
# Number of Clusters =  5

# %%
EDA.create_3d_scatter_plot(X_3reduced, xlabel="PC1", ylabel="PC2", zlabel="PC3", title="DBSCAN Clustering - 3D [0.8, 10]", labels=clusters)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# Perform dbscan algo
clusters = dbscan.perform_dbscan(X_3reduced, 0.8 , 5)

# Print the number of clusters
print("Number of Clusters = ",len(set(clusters)))
# Out:
# Number of Clusters =  4

# %%
EDA.create_3d_scatter_plot(X_3reduced, xlabel="PC1", ylabel="PC2", zlabel="PC3", title="DBSCAN Clustering - 3D [0.8, 5]", labels=clusters)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# Perform dbscan algo
clusters = dbscan.perform_dbscan(X_3reduced, 0.8 , 20)

# Print the number of clusters
print("Number of Clusters = ",len(set(clusters)))
# Out:
# Number of Clusters =  6

# %%
EDA.create_3d_scatter_plot(X_3reduced, xlabel="PC1", ylabel="PC2", zlabel="PC3", title="DBSCAN Clustering - 3D [0.8, 20]", labels=clusters)
# Out:
# <img src="data:image/png;base64,..." width="1000">
